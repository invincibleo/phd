# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'term', 'a', 'originated', 'term', 'of', 'originated', 'as']

# %%
print(np.shape(np.ndarray(shape=(2,1))))
# Out:
# (2, 1)

# %% [markdown]
# Train a skip-gram model.

# %%
batch_data, batch_labels = generate_batch(16, 2, 1)
print(batch_data)
# Out:
# [   59    59   156   156   128   128   742   742   477   477 10572 10572
#    134   134     1     1]

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.031621
# Nearest to may: melchizedek, mcelroy, eugen, kio, polyidus, addington, lancelot, bei,
# Nearest to other: hiawatha, artifice, faintly, ascent, plantarum, plotinus, baum, tank,
# Nearest to to: resorts, unwritten, cuisines, subclass, ruud, anticipates, flop, freiherr,
# Nearest to nine: motherland, shafts, decks, voce, ansi, number, semiconductors, artery,
# Nearest to for: agile, panacea, assistance, flavour, altman, acrobatics, line, malabo,
# Nearest to and: sussex, setter, fecture, alleviated, marjoram, isomorphisms, ballparks, pinnacle,
# Nearest to only: agni, utilizing, mcgowan, anthologized, corr, whewell, anheuser, halliday,
# Nearest to first: interactionism, insensitive, montage, fame, scarlett, jahangir, exploiting, telford,
# Nearest to most: chagos, electronica, valerie, col, tres, adherence, proportionate, longevity,
# Nearest to when: shehhi, wesleyan, externalization, rib, dolby, rg, horne, tamper,
# Nearest to than: mw, frazier, dionysus, diddley, dumbarton, tsiolkovsky, debated, pessimistic,
# Nearest to his: strokes, exporter, syncopation, munitions, buckwheat, tao, arginine, teachers,
# Nearest to that: diatomaceous, tract, unfortunately, wed, procedures, ediacaran, reestablish, responds,
# Nearest to system: karnataka, merkel, landowner, sextus, disciples, borrowers, hostility, dachshund,
# Nearest to are: madox, arcades, browsers, objected, yo, bombard, upn, portage,
# Nearest to the: sing, carnarvon, ducks, scrat, prostitute, kipling, connotations, se,
# Average loss at step 2000: 4.351237
# Average loss at step 4000: 3.867830
# Average loss at step 6000: 3.791292
# Average loss at step 8000: 3.685046
# Average loss at step 10000: 3.608651
# Nearest to may: could, can, eugen, cancels, would, pathogens, jonas, do,
# Nearest to other: hiawatha, tank, lovely, mandragora, robberies, faintly, walk, sunglasses,
# Nearest to to: nih, ephemeral, perceiving, not, abolish, loom, resorts, fennel,
# Nearest to nine: eight, six, five, seven, zero, four, three, two,
# Nearest to for: touched, panacea, in, assistance, of, metro, aelia, after,
# Nearest to and: or, in, jeep, ccitt, of, including, american, were,
# Nearest to only: agni, shetland, whewell, gigabytes, distorted, others, antenna, brentano,
# Nearest to first: mashed, insensitive, opolska, next, government, jahangir, leaving, hazael,
# Nearest to most: chagos, proportionate, tres, our, linde, dialysis, sourcewatch, legis,
# Nearest to when: through, if, shehhi, secant, jak, planck, spongebob, foods,
# Nearest to than: warbler, frazier, suffocation, feelings, dionysus, dipping, dish, refitted,
# Nearest to his: their, its, her, the, s, assists, abdullah, this,
# Nearest to that: which, it, wed, this, treblinka, reestablish, once, cth,
# Nearest to system: disciples, landowner, borrowers, rito, hostility, mockumentary, rationing, nicht,
# Nearest to are: were, is, including, have, was, and, decides, veneto,
# Nearest to the: a, this, his, its, an, their, any, submerged,
# Average loss at step 12000: 3.605584
# Average loss at step 14000: 3.569064
# Average loss at step 16000: 3.408042
# Average loss at step 18000: 3.458762
# Average loss at step 20000: 3.536277
# Nearest to may: can, could, would, will, cannot, should, incite, eugen,
# Nearest to other: many, some, all, critics, these, lovely, prefaced, spaniel,
# Nearest to to: will, would, not, can, may, could, ephemeral, posthuman,
# Nearest to nine: eight, six, seven, four, five, zero, three, two,
# Nearest to for: panacea, by, touched, in, wasteful, and, with, structural,
# Nearest to and: or, but, in, from, of, including, were, navies,
# Nearest to only: shetland, not, sentinels, contribute, whewell, sabres, geniuses, distortion,
# Nearest to first: next, insensitive, mashed, opolska, encompassing, own, hazael, grothendieck,
# Nearest to most: more, many, dialysis, trouble, monteverdi, adherence, pun, renormalization,
# Nearest to when: through, if, as, however, spongebob, was, rocker, repudiating,
# Nearest to than: or, warbler, suffocation, dish, percussive, frazier, allegiances, refitted,
# Nearest to his: their, her, its, the, your, some, abdullah, this,
# Nearest to that: which, assimilated, but, wed, plekhanov, because, however, offense,
# Nearest to system: disciples, landowner, energy, menacing, borrowers, apparel, nicht, scaffolding,
# Nearest to are: were, is, was, have, veneto, lubricants, including, compilers,
# Nearest to the: its, this, an, their, some, any, his, vivant,
# Average loss at step 22000: 3.503156
# Average loss at step 24000: 3.486116
# Average loss at step 26000: 3.485010
# Average loss at step 28000: 3.473936
# Average loss at step 30000: 3.507374
# Nearest to may: can, would, could, will, should, cannot, must, might,
# Nearest to other: many, these, some, magnon, prefaced, critics, traverses, are,
# Nearest to to: can, would, will, may, might, rhea, ephemeral, under,
# Nearest to nine: eight, seven, six, five, four, three, zero, births,
# Nearest to for: of, panacea, wasteful, including, touched, against, liv, with,
# Nearest to and: or, but, who, in, syphilis, of, from, tyrant,
# Nearest to only: not, geniuses, episcopalian, cgpm, until, miocene, submissive, still,
# Nearest to first: next, mashed, same, second, opolska, encompassing, hazael, insensitive,
# Nearest to most: more, trouble, many, renormalization, among, insulting, dialysis, tres,
# Nearest to when: if, after, before, through, where, gave, however, but,
# Nearest to than: warbler, suffocation, percussive, refitted, allegiances, dish, dionysus, foundational,
# Nearest to his: their, her, its, the, s, your, this, a,
# Nearest to that: which, wed, what, however, but, machado, this, stormed,
# Nearest to system: systems, menacing, landowner, energy, disciples, borrowers, progressives, debut,
# Nearest to are: were, have, is, include, be, including, these, other,
# Nearest to the: their, its, his, vivant, a, culminate, any, this,
# Average loss at step 32000: 3.502150
# Average loss at step 34000: 3.490202
# Average loss at step 36000: 3.451911
# Average loss at step 38000: 3.300676
# Average loss at step 40000: 3.424538
# Nearest to may: can, could, would, will, should, must, might, cannot,
# Nearest to other: different, hutcheson, prefaced, various, some, others, critics, many,
# Nearest to to: could, will, can, would, may, alpinus, and, in,
# Nearest to nine: eight, seven, six, five, zero, four, three, one,
# Nearest to for: lingual, touched, panacea, by, in, including, nfs, through,
# Nearest to and: or, but, in, where, to, barlaam, gauss, swede,
# Nearest to only: not, cgpm, geniuses, episcopalian, konqueror, problem, transplanted, directly,
# Nearest to first: next, second, last, opolska, knights, encompassing, mashed, same,
# Nearest to most: more, renormalization, highly, dystopian, less, trouble, among, many,
# Nearest to when: if, before, through, after, where, gave, but, however,
# Nearest to than: or, warbler, much, foundational, refitted, suffocation, repressive, dionysus,
# Nearest to his: their, her, its, your, s, the, my, houdini,
# Nearest to that: which, what, this, however, wed, ediacaran, who, instead,
# Nearest to system: systems, menacing, landowner, debut, disciplined, scaffolding, network, hesychast,
# Nearest to are: were, have, include, is, but, these, compilers, be,
# Nearest to the: their, its, this, a, his, any, some, each,
# Average loss at step 42000: 3.442115
# Average loss at step 44000: 3.452652
# Average loss at step 46000: 3.449609
# Average loss at step 48000: 3.357560
# Average loss at step 50000: 3.381056
# Nearest to may: can, would, could, should, will, must, might, cannot,
# Nearest to other: various, many, different, hutcheson, prefaced, traverses, others, some,
# Nearest to to: would, unwritten, must, may, could, can, might, ephemeral,
# Nearest to nine: eight, seven, six, five, three, zero, four, two,
# Nearest to for: shear, against, lingual, touched, panacea, structural, including, nusa,
# Nearest to and: or, but, including, rented, barlaam, schwerin, s, jeep,
# Nearest to only: not, primitivism, cgpm, first, konqueror, speedily, geniuses, usually,
# Nearest to first: second, next, last, opolska, mashed, encompassing, hazael, same,
# Nearest to most: more, less, highly, renormalization, insulting, many, dialysis, all,
# Nearest to when: if, after, before, although, while, where, however, because,
# Nearest to than: much, refitted, or, warbler, repressive, dish, accorded, but,
# Nearest to his: their, her, its, your, my, the, s, our,
# Nearest to that: which, however, wed, stormed, assimilated, reestablish, what, today,
# Nearest to system: systems, menacing, landowner, scaffolding, energy, disciplined, noether, wakes,
# Nearest to are: were, have, is, although, include, shave, these, sentinel,
# Nearest to the: its, their, this, his, a, cot, some, nasalized,
# Average loss at step 52000: 3.436402
# Average loss at step 54000: 3.423101
# Average loss at step 56000: 3.436823
# Average loss at step 58000: 3.398179
# Average loss at step 60000: 3.389566
# Nearest to may: can, would, should, could, will, might, must, cannot,
# Nearest to other: various, different, many, prefaced, hutcheson, several, spaniel, others,
# Nearest to to: would, ephemeral, rhea, might, can, could, must, alpinus,
# Nearest to nine: eight, six, seven, four, five, zero, three, one,
# Nearest to for: including, of, intuitionistic, without, phoenician, liv, stroke, reproducible,
# Nearest to and: or, but, including, although, in, like, tain, than,
# Nearest to only: attackers, konqueror, yet, first, always, until, miocene, princip,
# Nearest to first: next, second, last, mashed, lafayette, same, encompassing, hedge,
# Nearest to most: more, many, highly, less, some, very, use, both,
# Nearest to when: if, before, although, after, where, because, during, while,
# Nearest to than: much, refitted, or, but, warbler, dish, no, dde,
# Nearest to his: her, their, its, your, my, redaction, our, masovia,
# Nearest to that: which, what, this, however, stormed, then, reestablish, it,
# Nearest to system: systems, landowner, energy, network, disciplined, wakes, menacing, andorran,
# Nearest to are: were, is, have, include, including, those, hiawatha, removes,
# Nearest to the: their, its, a, this, dirt, our, his, some,
# Average loss at step 62000: 3.241711
# Average loss at step 64000: 3.254955
# Average loss at step 66000: 3.402000
# Average loss at step 68000: 3.392900
# Average loss at step 70000: 3.356747
# Nearest to may: can, would, should, could, will, might, must, cannot,
# Nearest to other: various, different, some, others, hutcheson, these, prefaced, such,
# Nearest to to: would, must, can, will, might, may, ephemeral, unwritten,
# Nearest to nine: eight, six, seven, five, four, three, zero, one,
# Nearest to for: in, including, lingual, against, without, of, after, revisionism,
# Nearest to and: or, but, including, tain, while, like, nusa, see,
# Nearest to only: yet, transplanted, konqueror, miocene, always, directly, not, even,
# Nearest to first: second, next, last, same, original, encompassing, opolska, lafayette,
# Nearest to most: more, less, many, highly, some, very, both, among,
# Nearest to when: if, before, although, because, while, where, however, after,
# Nearest to than: refitted, or, much, but, allegiances, hydras, and, warbler,
# Nearest to his: her, their, its, your, my, our, the, photorealistic,
# Nearest to that: which, however, what, but, this, reestablish, wed, stormed,
# Nearest to system: systems, network, andorran, alces, disciplined, varepsilon, backfired, landowner,
# Nearest to are: were, is, include, have, although, including, while, these,
# Nearest to the: their, a, its, any, this, some, these, his,
# Average loss at step 72000: 3.376300
# Average loss at step 74000: 3.346089
# Average loss at step 76000: 3.314483
# Average loss at step 78000: 3.344895
# Average loss at step 80000: 3.378924
# Nearest to may: can, should, would, could, will, might, must, cannot,
# Nearest to other: various, western, different, many, prefaced, others, hutcheson, corridors,
# Nearest to to: would, ephemeral, transcending, picatinny, will, could, alpinus, must,
# Nearest to nine: eight, seven, five, six, four, three, zero, cet,
# Nearest to for: including, mascarene, nfs, after, panacea, against, during, touched,
# Nearest to and: or, including, but, than, import, while, brentwood, rented,
# Nearest to only: always, either, first, princip, necessary, even, miocene, ultimate,
# Nearest to first: second, last, next, final, same, encompassing, third, antonia,
# Nearest to most: more, less, many, highly, some, especially, among, playground,
# Nearest to when: if, after, before, during, although, though, where, then,
# Nearest to than: much, or, refitted, and, warbler, hydras, but, percussive,
# Nearest to his: her, their, its, my, your, our, the, personal,
# Nearest to that: which, however, stormed, reestablish, wed, holistic, machado, huber,
# Nearest to system: systems, network, program, disciplined, milit, pungent, alces, enya,
# Nearest to are: were, have, include, although, is, including, these, plummer,
# Nearest to the: its, their, this, culminate, his, a, another, verifiable,
# Average loss at step 82000: 3.401027
# Average loss at step 84000: 3.407088
# Average loss at step 86000: 3.388397
# Average loss at step 88000: 3.349091
# Average loss at step 90000: 3.365304
# Nearest to may: can, should, could, will, would, must, might, cannot,
# Nearest to other: various, different, corridors, hutcheson, ropes, editing, individual, prefaced,
# Nearest to to: would, will, decapitate, unwritten, alpinus, could, hn, nessus,
# Nearest to nine: eight, seven, six, five, four, three, zero, births,
# Nearest to for: including, against, after, intuitionistic, striping, without, during, mascarene,
# Nearest to and: or, but, schwerin, including, amenities, authorize, colorful, vr,
# Nearest to only: princip, miocene, statistically, yastrzemski, even, always, competitiveness, speedily,
# Nearest to first: last, second, next, encompassing, original, same, best, previous,
# Nearest to most: more, less, some, many, highly, among, especially, particularly,
# Nearest to when: if, before, after, while, where, because, though, although,
# Nearest to than: much, refitted, hydras, or, vaccines, warbler, allegiances, no,
# Nearest to his: her, their, its, your, my, our, the, s,
# Nearest to that: which, however, what, stormed, reestablish, wed, but, laren,
# Nearest to system: systems, network, process, point, program, varepsilon, enya, ciprofloxacin,
# Nearest to are: were, is, these, include, have, although, being, hiawatha,
# Nearest to the: its, their, his, a, this, thoth, hype, any,
# Average loss at step 92000: 3.398129
# Average loss at step 94000: 3.249722
# Average loss at step 96000: 3.354556
# Average loss at step 98000: 3.244168
# Average loss at step 100000: 3.355962
# Nearest to may: can, should, could, would, must, will, might, cannot,
# Nearest to other: various, different, hutcheson, others, transliteration, guadalcanal, ropes, corridors,
# Nearest to to: will, could, would, must, can, ephemeral, should, diagonals,
# Nearest to nine: eight, seven, six, five, four, three, zero, cet,
# Nearest to for: if, including, against, when, lingual, after, nfs, mascarene,
# Nearest to and: or, but, while, although, nor, however, who, of,
# Nearest to only: princip, miocene, yastrzemski, until, iamblichus, twig, subunit, even,
# Nearest to first: last, next, second, encompassing, third, previous, final, best,
# Nearest to most: more, less, highly, especially, among, some, particularly, extremely,
# Nearest to when: if, while, before, where, although, after, because, though,
# Nearest to than: or, much, refitted, warbler, hydras, and, slightly, vaccines,
# Nearest to his: her, their, my, its, your, the, our, s,
# Nearest to that: which, what, however, stormed, where, ediacaran, pirin, but,
# Nearest to system: systems, disciplined, process, alces, network, program, pungent, landowner,
# Nearest to are: were, have, include, these, is, while, although, including,
# Nearest to the: his, your, their, its, this, her, our, a,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
